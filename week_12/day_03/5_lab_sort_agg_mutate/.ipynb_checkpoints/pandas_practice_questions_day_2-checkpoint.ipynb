# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#Core-questions" data-toc-modified-id="Core-questions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Core questions</a></span></li><li><span><a href="#Extension-questions" data-toc-modified-id="Extension-questions-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Extension questions</a></span></li><li><span><a href="#Core-question-solutions" data-toc-modified-id="Core-question-solutions-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Core question solutions</a></span></li><li><span><a href="#Extension-question-solutions" data-toc-modified-id="Extension-question-solutions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Extension question solutions</a></span></li></ul></div>

# %% [markdown]
# <p style="page-break-after:always;"></p>

# %% [markdown]
# # Setup
#
# Let's load in the datasets we need for the practice session. They correspond to cuts of the tables from the `omni_pool` database we used earlier in the course. The idea in this session is to try to do in `pandas` some of the operations we coded in `SQL` (with a bit of variation to keep things fresh)!
#
# We would recommend you try all of the Core Questions below, and then move on to the Extension Questions if time permits.
#
# **Note** - some of the questions should be attempted only after you have covered the material on joining, melting and pivoting `DataFrame`s on day 3. We have marked these questions below.

# %%
import pandas as pd

employees = pd.read_csv('data/omni_employees.csv', parse_dates=['start_date'])
pay_details = pd.read_csv('data/omni_pay_details.csv')
teams = pd.read_csv('data/omni_teams.csv')
committees = pd.read_csv('data/omni_committees.csv')
employees_committees = pd.read_csv('data/omni_employees_committees.csv')

# %% [markdown]
# # Core questions
#
# ***Q1.*** Perform some basic data exploration of the `employees` `DataFrame`. Methods and attributes to consider using here include `.info()`, `.describe()` and `.shape`. In particular, answer the following:
#
# - What data type is each column?
# - How many unique values are there in `department` and `country`?
# - What are the minimum and maximum of `salary`?
# - How many rows are there in the `DataFrame`?
#
# ***
#
# ***Q2.*** Find all the details of `employees` who work in the 'Legal' `department`.
#
# ***
#
# ***Q3.*** How many `employees` are based in Japan?
#
# **Hint** - Running `.count()` on the `id` column might help here, or you could use the `.shape` attribute
#
# ***
#
# ***Q4.*** [**Harder**] In the question above, we suggested you `.count()` the `id` column (i.e. treating it like a `SQL` primary key). But we haven't yet shown that `id` satisfies the associated requirements. Confirm that the number of unique values in `id` equals the number of rows in `employees`.
#
# **Hints**
#
# * The `.shape` attribute of the `employees` `DataFrame` and the `.nunique()` method can be combined in one line of code to show this
# * Remember that `.shape` returns a `tuple`: which element of the `tuple` do you need?
#
# ***
#
# ***Q5.*** How many `employees` have a missing `email` address?
#
# ***
#
# ***Q6.*** Calculate the mean `salary` of `employees` in the 'Legal' `department`.
#
# ***
#
# ***Q7.*** Obtain the `first_name`, `last_name` and `salary` of all `employees` sorted in descending order of `salary`.
#
# ***
#
# ***Q8.*** Obtain the `first_name`, `last_name` and `country` of `employees` ordered first alphabetically by `country` and then alphabetically by `last_name`.
#
# ***
#
# ***Q9.*** [**Harder**] Obtain the `first_name`, `last_name` and `email` address of all `employees` in the 'Engineering' `department` who work 0.5 `fte_hours` or greater.
#
# ***
#
# ***Q10.*** [**Harder**] Calculate the mean `salary` of all `employees` who are members either of the 'Legal' or the 'Accounting' `department`s.
#
# **Hint** - The `.isin()` method let's you do this in one line of code, without having to manually combine means for the two `department`s
#
# ***
#
# ***Q11.*** [**Harder**] How many pension enrolled `employees` are based outside of France, Austria or Ireland?
#
# **Hint** - Remember `~` is the negation operator in `pandas`
#
# ***
#
# ***Q12.*** Add a new column `effective_salary` to `employees` containing `salary` multiplied by `fte_hours`.
#
# ***
#
# ***Q13.*** Obtain the details of all those `employees` whose `last_name` starts with 'R'.
#
# **Hint** - Perhaps one of the `StringMethods` can be used: you can access these via the `.str` accessor
#
# ***
#
# ***Q14.*** [**Harder**] Are there any `employees` whose `last_name` does not start with a capital letter?
#
# **Hints**
#
# * Assume there are no missing values in `last_name`
# * The `.str.startswith()` method won't accept regex, unfortunately
# * Regex anchors may help here: `^` means 'the position just before the start of a string, and `$` means 'the position just after the end of a string'
# * Remember `~` is the negation operator in `pandas`
#
# ***
#
# ***Q15.*** Create a new column `start_month` in `employees`, containing the month in which an employee started with the corporation. Make `start_month` a string rather than a number, e.g. 'June' rather than '6'.
#
# **Hint** - Remember you can access `DatetimeProperties` using the `.dt` accessor
#
# ***
#
# ***Q16.*** Obtain a table showing the number of `employees` in each `department`.
#
# **Hint** - Think **split-apply-combine**
#
# ***
#
# ***Q17.*** Obtain a count of the number of `employees` enrolled and not enrolled in the pension scheme. Ignore missing values in `pension_enrol` for now.
#
# ***
#
# ***Q18.*** [**Harder**] Repeat your analysis from Question 17 above, but this time fill any missing values in `pension_enrol` with the string 'Missing'.
#
# **Hint** - the `.fillna()` method will help here
#
# ***
#
# ***Q19.*** Obtain a count by `department` of the number of `employees` enrolled and not enrolled in the pension scheme. Include missing values or otherwise fill them with the string 'Missing' as in the question above. [**Harder**] - Change the header of the column containing count values to 'num_employees'.
#
# **Hints**
#
# * You need to `.groupby()` on multiple columns
# * Is there an argument to `.groupby()` that lets you keep missing values?
# * The `.agg()` method can take arguments that let you specify the output column name for an aggregator
#
# ***
#
# ***Q20.*** Obtain a table showing all `employees` details together with a column `team_name` containing the name of their team.
#
# **Attempt this question only after the lesson on joining, melting and pivoting `DataFrame`s on day 3**
#
# **Hints**
#
# * This will require joining `employees` to `teams`
# * You can `.drop()` unwanted columns from `teams` after the join
# * The `.rename()` method lets you change column names
#
# ***
#
# ***Q21.*** [**Harder**] Obtain a table showing `team_name` together with a count of the `num_employees` in each team.
#
# **Attempt this question only after the lesson on joining, melting and pivoting `DataFrame`s on day 3**
#
# **Hints**
#
# * You will need to join `employees` to `teams`
# * The `.rename()` method lets you rename a column
# * The `.agg()` method can take arguments that let you specify the output column name for an aggregator
#
# ***
#
# ***Q22.*** [**Harder**] Obtain a table showing the `id`, `first_name`, `last_name` and `department` of any `employees` lacking both a `local_account_no` and `local_sort_code` in their `pay_details`.
#
# **Attempt this question only after the lesson on joining, melting and pivoting `DataFrame`s on day 3**
#
# **Hints**
#
# * Filter `pay_details` down to those rows lacking both a `local_account_no` and `local_sort_code`, and then join that to `employees`
# * The `.all()` method applied over columns can help here
#
# # Extension questions
#
# ***Q1.*** Investigate the use of the `.where()` function in the `numpy` package to add a column `hours_class` to `employees` containing the value 'low' when `fte_hours` is 0.5 or less and 'high' otherwise.
#
# **Hint** - Import `numpy` as `np`, and `.where()` will then be available as `np.where()`
#
# ***
#
# ***Q2.*** Are there any `employees` with invalid `email` addresses?
#
# **Hint** - Count non-null `email` addresses that don't match a reasonable regex pattern for a valid email address
#
# ***
#
# ***Q3.*** How many of the `employees` serve on one or more `committees`?
#
# **Hints**
#
# * This requires only the `employees_committees` `DataFrame`
# * Think about distinct `employees`
#
# ***
#
# ***Q4.*** Get the full employee details (including committee name) of any committee members based in the Ukraine.
#
# **Attempt this question only after the lesson on joining, melting and pivoting `DataFrame`s on day 3**
#
# **Hints**
#
# * This is a many-to-many join, so three `DataFrame`s will be involved: `employees`, `committees` and `employees_committees`
# * The `.query()` method lets you do all this in one line of code
#
# ***
#
# ***Q5.*** Obtain a table with column `start_month` containing the names of months and column `num_started` showing the number of `employees` who started in that month (in any year). The table should contain 12 rows, one for each month, and be ordered 'January', 'February', 'March' and so forth, in ascending calendar order.
#
# **Hints**
#
# * Extracting both the `.month_name()` and `.month` from `start_date` might help here
# * We used `.assign()` to create the two new date feature columns before any subsequent operations
#
# # Core question solutions
#
# ***Q1.*** Perform some basic data exploration of the `employees` `DataFrame`. Methods and attributes to consider using here include `.info()`, `.describe()` and `.shape`. In particular, answer the following:
#     - What data type is each column?
#     - How many unique values are there in `department` and `country`?
#     - What are the minimum and maximum of `salary`?
#     - How many rows are there in the `DataFrame`?

# %%
# the .info() method gives us the data type of each column
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   first_name     974 non-null    object
#  2   last_name      1000 non-null   object
#  3   email          878 non-null    object
#  4   department     1000 non-null   object
#  5   team_id        1000 non-null   int64
#  6   grade          980 non-null    float64
#  7   country        1000 non-null   object
#  8   fte_hours      1000 non-null   float64
#  9   pension_enrol  958 non-null    object
#  10  salary         935 non-null    float64
#  11  pay_detail_id  1000 non-null   int64
#  12  start_date     926 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(3), object(6)
# memory usage: 101.7+ KB

# %%
# .describe() with  include='all' gives basic overview of values in columns
employees.describe(include='all')
# Out:
# <ipython-input-3-f1ea54052a3c>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   employees.describe(include='all')
#                  id first_name  last_name               email department  \
# count   1000.000000        974       1000                 878       1000
# unique          NaN        918        992                 878         12
# top             NaN    Claudio  Caldayrou  jikinslb@fotki.com      Legal
# freq            NaN          3          2                   1        102
# first           NaN        NaN        NaN                 NaN        NaN
# last            NaN        NaN        NaN                 NaN        NaN
# mean     500.500000        NaN        NaN                 NaN        NaN
# std      288.819436        NaN        NaN                 NaN        NaN
# min        1.000000        NaN        NaN                 NaN        NaN
# 25%      250.750000        NaN        NaN                 NaN        NaN
# 50%      500.500000        NaN        NaN                 NaN        NaN
# 75%      750.250000        NaN        NaN                 NaN        NaN
# max     1000.000000        NaN        NaN                 NaN        NaN
#
#            team_id       grade country    fte_hours pension_enrol  \
# count   1000.00000  980.000000    1000  1000.000000           958
# unique         NaN         NaN     130          NaN             2
# top            NaN         NaN   China          NaN           Yes
# freq           NaN         NaN     192          NaN           488
# first          NaN         NaN     NaN          NaN           NaN
# last           NaN         NaN     NaN          NaN           NaN
# mean       5.39900    0.189796     NaN     0.627750           NaN
# std        2.88342    0.392340     NaN     0.278514           NaN
# min        1.00000    0.000000     NaN     0.250000           NaN
# 25%        3.00000    0.000000     NaN     0.500000           NaN
# 50%        5.00000    0.000000     NaN     0.750000           NaN
# 75%        8.00000    0.000000     NaN     0.750000           NaN
# max       10.00000    1.000000     NaN     1.000000           NaN
#
#               salary  pay_detail_id           start_date
# count     935.000000    1000.000000                  926
# unique           NaN            NaN                  894
# top              NaN            NaN  1992-06-05 00:00:00
# freq             NaN            NaN                    3
# first            NaN            NaN  1990-01-25 00:00:00
# last             NaN            NaN  2019-04-24 00:00:00
# mean    59929.568984     500.500000                  NaN
# std     22891.672558     288.819436                  NaN
# min     20063.000000       1.000000                  NaN
# 25%     40103.500000     250.750000                  NaN
# 50%     59917.000000     500.500000                  NaN
# 75%     78917.500000     750.250000                  NaN
# max     99889.000000    1000.000000                  NaN

# %% [markdown]
# We see that we have 12 unique values of `department`, 130 unique values of `country`, the minimum `salary` is 20,063 and the maximum `salary` is 99,889.

# %%
# .shape gives (num_rows, num_columns)
employees.shape
# Out:
# (1000, 13)

# %% [markdown]
# ***Q2.*** Find all the details of `employees` who work in the 'Legal' `department`

# %%
employees.loc[employees.department == 'Legal']
# or
employees.query("department == 'Legal'")
# Out:
#       id first_name    last_name                           email department  \
# 0      1      Ibbie     Roscrigg            iroscrigg0@google.fr      Legal
# 2      4     Osmund       Kittel          okittel3@bloomberg.com      Legal
# 10    12  Thorstein         Garr                  tgarrb@icio.us      Legal
# 17    19      Robby     Harragin                             NaN      Legal
# 35    37     Franky        Idell          fidell10@economist.com      Legal
# ..   ...        ...          ...                             ...        ...
# 942  944     Velvet     Mellodey  vmellodeyq7@huffingtonpost.com      Legal
# 958  960      Joela  McClenaghan    jmcclenaghanqn@aboutads.info      Legal
# 965  967   Elsinore        Stein                             NaN      Legal
# 980  982    Maurita      Sirkett             msirkettr9@webs.com      Legal
# 992  994       Dani    Berthelet             dbertheletrl@si.edu      Legal
#
#      team_id  grade         country  fte_hours pension_enrol   salary  \
# 0          9    0.0         Nigeria       0.25           Yes  97667.0
# 2         10    0.0  United Kingdom       1.00           Yes  51200.0
# 10         1    0.0           China       0.75            No  39926.0
# 17        10    0.0     South Korea       0.25           Yes  70830.0
# 35         4    0.0          Sweden       1.00           Yes      NaN
# ..       ...    ...             ...        ...           ...      ...
# 942        2    0.0     Philippines       0.75           Yes  70961.0
# 958       10    0.0           China       1.00           Yes  56952.0
# 965        2    0.0        Malaysia       1.00           Yes      NaN
# 980        6    0.0         Ecuador       0.25            No  97989.0
# 992        5    1.0           Chile       1.00           Yes  85316.0
#
#      pay_detail_id start_date
# 0                1 2014-12-25
# 2                4 2007-09-06
# 10              12 2012-03-23
# 17              19 1998-07-20
# 35              37 1990-06-06
# ..             ...        ...
# 942            944        NaT
# 958            960 2011-02-19
# 965            967 2013-01-25
# 980            982 2006-12-09
# 992            994 1999-09-24
#
# [102 rows x 13 columns]

# %% [markdown]
# ***Q3.*** How many `employees` are based in Japan?
#
# **Hint** - Running `.count()` on the `id` column might help here, or you could use the `.shape` attribute

# %%
employees.loc[employees.country == 'Japan', 'id'].count()
# or
employees.loc[employees.country == 'Japan'].shape[0]
# Out:
# 26

# %% [markdown]
# ***Q4.*** [**Harder**] In the question above, we suggested you `.count()` the `id` column (i.e. treating it like a `SQL` primary key). But we haven't yet shown that `id` satisfies the associated requirements. Confirm that the number of unique values in `id` equals the number of rows in `employees`.
#
# **Hints**
#
# * The `.shape` attribute of the `employees` `DataFrame` and the `.nunique()` method can be combined in one line of code to show this
# * Remember that `.shape` returns a `tuple`: which element of the `tuple` do you need?

# %%
employees.id.nunique() == employees.shape[0]
# Out:
# True

# %% [markdown]
# ***Q5.*** How many `employees` have a missing `email` address?

# %%
employees.loc[employees.email.isna(), 'id'].count()

#or
employees.loc[employees.email.isna()].shape[0]
# Out:
# 122

# %% [markdown]
# ***Q6.*** Calculate the mean `salary` of `employees` in the 'Legal' `department`.

# %%
employees.loc[employees.department=='Legal'].salary.mean()
# Out:
# 56503.947916666664

# %% [markdown]
# ***Q7.*** Obtain the `first_name`, `last_name` and `salary` of all `employees` sorted in descending order of `salary`.

# %%
employees.loc[:, ['first_name', 'last_name', 'salary']].sort_values('salary', ascending=False)
# Out:
#      first_name  last_name   salary
# 758     Gustave    Truwert  99889.0
# 945     Patrice     Chitty  99853.0
# 857       Corny      Yearn  99798.0
# 963      Brucie   Ceschini  99634.0
# 198     Katinka     Peffer  99565.0
# ..          ...        ...      ...
# 922       Claus   Hadigate      NaN
# 940      Isobel   McMillan      NaN
# 953    Martainn  McCaughan      NaN
# 965    Elsinore      Stein      NaN
# 983  Bernardine    Brasier      NaN
#
# [1000 rows x 3 columns]

# %% [markdown]
# ***Q8.*** Obtain the `first_name`, `last_name` and `country` of `employees` ordered first alphabetically by `country` and then alphabetically by `last_name`.

# %%
employees.loc[:, ['first_name', 'last_name', 'country']].sort_values(['country', 'last_name'])
# Out:
#     first_name  last_name      country
# 929       Abeu     Pawden  Afghanistan
# 176      Trixi  Pickvance  Afghanistan
# 255      Vance     Ratlee  Afghanistan
# 792      Beale    Raynard  Afghanistan
# 338    Bentlee        Toy  Afghanistan
# ..         ...        ...          ...
# 691   Ebenezer     Roseby        Yemen
# 421     Gretta     Zealey        Yemen
# 358     Farrel    Clethro       Zambia
# 920       Conn     Robiot       Zambia
# 623      Aaron       Tack       Zambia
#
# [1000 rows x 3 columns]

# %% [markdown]
# ***Q9.*** [**Harder**] Obtain the `first_name`, `last_name` and `email` address of all `employees` in the 'Engineering'  `department` who work 0.5 `fte_hours` or greater.

# %%
employees.loc[
    (employees.department == 'Engineering') & (employees.fte_hours >= 0.5), 
    ['first_name', 'last_name', 'email']
]
# Out:
#     first_name   last_name                     email
# 3      Feodora    Dumingos   fdumingos4@bandcamp.com
# 37     Sybilla    Lodewick     slodewick12@salon.com
# 55       Rheba      Booton  rbooton1k@bravesites.com
# 98      Launce       Feyer                       NaN
# 99        Shep     Loveday    sloveday2s@twitpic.com
# ..         ...         ...                       ...
# 948      Shell        Over           soverqd@icio.us
# 950     Manuel  Ferrarotti     mferrarottiqf@ovh.net
# 954      Terry    Sawforde       tsawfordeqj@mit.edu
# 977        Tam        Tsar        ttsarr6@smh.com.au
# 984     Pennie    Hanhardt    phanhardtrd@flavors.me
#
# [61 rows x 3 columns]

# %% [markdown]
# ***Q10.*** [**Harder**] Calculate the mean `salary` of all `employees` who are members either of the 'Legal' or the 'Accounting' `department`s.
#
# **Hint** - The `.isin()` method let's you do this in one line of code, without having to manually combine means for the two `department`s

# %%
employees[employees.department.isin(['Legal', 'Accounting'])].salary.mean()
# Out:
# 58213.132530120485

# %% [markdown]
# ***Q11.*** [**Harder**] How many pension enrolled `employees` are based outside of France, Austria or Ireland?
#
# **Hint** - Remember `~` is the negation operator in `pandas`

# %%
employees.loc[
    (employees.pension_enrol == 'Yes') &
    (~employees.country.isin(['France', 'Austria', 'Ireland'])),
    'id'
].count()

# or 
employees.loc[
    (employees.pension_enrol == 'Yes') &
    (~employees.country.isin(['France', 'Austria', 'Ireland']))
].shape[0]
# Out:
# 473

# %% [markdown]
# ***Q12.*** Add a new column `effective_salary` to `employees` containing `salary` multiplied by `fte_hours`

# %%
employees.loc[:, 'effective_salary'] = employees.salary * employees.fte_hours
employees
# Out:
#        id first_name  last_name                    email  \
# 0       1      Ibbie   Roscrigg     iroscrigg0@google.fr
# 1       2      Sylas  Smallcomb                      NaN
# 2       4     Osmund     Kittel   okittel3@bloomberg.com
# 3       5    Feodora   Dumingos  fdumingos4@bandcamp.com
# 4       6      Peter    de Vaen         pdevaen5@mail.ru
# ..    ...        ...        ...                      ...
# 995   997    Carlina      Pirot     cpirotro@archive.org
# 996   998     Wileen     Skones        wskonesrp@hhs.gov
# 997   999      Willy     Dulake  wdulakerq@webeden.co.uk
# 998  1000  Maribelle      Rotge    mrotgerr@google.co.uk
# 999     3     Saleem      Adame       sadame3@utexas.edu
#
#                    department  team_id  grade         country  fte_hours  \
# 0                       Legal        9    0.0         Nigeria       0.25
# 1                    Training        3    0.0       Macedonia       0.75
# 2                       Legal       10    0.0  United Kingdom       1.00
# 3                 Engineering        2    0.0       Indonesia       0.50
# 4          Product Management        2    1.0          Greece       0.50
# ..                        ...      ...    ...             ...        ...
# 995      Business Development        2    0.0           China       1.00
# 996                Accounting        4    0.0          Uganda       0.25
# 997      Business Development        9    0.0        Colombia       0.25
# 998  Research and Development        5    0.0          Brazil       0.50
# 999                  Services        9    0.0        Portugal       0.25
#
#     pension_enrol   salary  pay_detail_id start_date  effective_salary
# 0             Yes  97667.0              1 2014-12-25          24416.75
# 1              No  48556.0              2 1991-08-01          36417.00
# 2             Yes  51200.0              4 2007-09-06          51200.00
# 3             Yes  60460.0              5 1990-03-28          30230.00
# 4              No  32060.0              6 1992-06-30          16030.00
# ..            ...      ...            ...        ...               ...
# 995            No  63189.0            997 2018-08-30          63189.00
# 996           Yes  81734.0            998 2000-11-26          20433.50
# 997            No  21590.0            999 2018-08-01           5397.50
# 998           Yes  62531.0           1000 2019-03-09          31265.50
# 999           Yes  91749.0              3 1999-10-09          22937.25
#
# [1000 rows x 14 columns]

# %% [markdown]
# ***Q13.*** Obtain the details of all those `employees` whose `last_name` starts with 'R'.
#
# **Hint** - Perhaps one of the `StringMethods` can be used: you can access these via the `.str` accessor

# %%
employees[employees.last_name.str.startswith('R')]
# Out:
#        id  first_name    last_name                          email  \
# 0       1       Ibbie     Roscrigg           iroscrigg0@google.fr
# 20     22       Carie     Rimbault          crimbaultl@dyndns.org
# 70     72     Leopold     Rowlands      lrowlands1z@over-blog.com
# 83     85       Iorgo      Rickaby         irickaby2c@auda.org.au
# 93     95      Elissa   Rawsthorne    erawsthorne2m@geocities.com
# 110   112     Spencer   Rollinshaw  srollinshaw33@paginegialle.it
# 153   155       Angie        Rohlf         arohlf4a@cafepress.com
# 154   156        Rodd         Rabl             rrabl4b@elpais.com
# 158   160      Georgi    Rosenthal           grosenthal4f@dot.gov
# 196   198        Marv     Robjents     mrobjents5h@eventbrite.com
# 216   218      Florri       Reedie         freedie61@hubpages.com
# 226   228      Regine          Roj       rroj6b@sciencedirect.com
# 255   257       Vance       Ratlee            vratlee74@webmd.com
# 261   263     Lurlene       Rodger          lrodger7a@auda.org.au
# 268   270       Griff       Ridder           gridder7h@flickr.com
# 271   273      Gwynne     Robertot        grobertot7k@latimes.com
# 289   291      Benoit  Reisenstein     breisenstein82@dropbox.com
# 310   312         NaN      Radmore               lradmore8n@51.la
# 311   313    Maryjane     Reynalds       mreynalds8o@hatena.ne.jp
# 339   341       Salem        Ryrie               sryrie9g@gnu.org
# 352   354         NaN     Ricardet          pricardet9t@wikia.com
# 355   357   Theresita      Roughey             troughey9w@unc.edu
# 366   368       Cecil    Reucastle           creucastlea7@last.fm
# 394   396        Hugh         Read              hreadaz@yahoo.com
# 406   408      Weylin       Rother               wrotherbb@go.com
# 419   421      Boonie       Raccio          bracciobo@t-online.de
# 427   429    Immanuel    Robottham       irobotthambw@state.tx.us
# 444   446       Bruis        Rathe           brathecd@jiathis.com
# 446   448     Gwyneth    Ragbourne      gragbournecf@hubpages.com
# 454   456       Tasia     Robardey                            NaN
# 533   535      Cullen        Ribey          cribeyeu@engadget.com
# 563   565        Bell       Riolfi    briolfifo@sciencedirect.com
# 567   569       Drusy      Raiston         draistonfs@alibaba.com
# 582   584  Batholomew  Rossborough                            NaN
# 616   617      Kenyon    Restorick         krestorickh4@issuu.com
# 677   678    Domeniga  Ravenscroft       dravenscroftit@imgur.com
# 686   687        Kath       Robens              krobensj2@mtv.com
# 691   692    Ebenezer       Roseby              erosebyj7@ted.com
# 713   715   Richmound        Raith   rraithju@merriam-webster.com
# 762   764     Bennett         Rapp                 brappl7@si.edu
# 780   782       Gordy         Root                 grootlp@i2i.jp
# 792   794       Beale      Raynard             braynardm1@mail.ru
# 795   797       Angil      Rothert             arothertm4@mac.com
# 824   826        Andy     Ranvoise    aranvoisemx@kickstarter.com
# 858   860      Kizzie      Rabidge            krabidgenv@jugem.jp
# 861   863      Kristy        Rowet        krowetny@washington.edu
# 881   883      Halsey     Reedshaw    hreedshawoi@dailymail.co.uk
# 901   903     Raleigh       Ropkes            rropkesp2@google.nl
# 902   904      Gianni     Redfearn         gredfearnp3@uol.com.br
# 919   921     Gardner        Routh        grouthpk@feedburner.com
# 920   922        Conn       Robiot          crobiotpl@storify.com
# 974   976   Fransisco          Rue        fruer3@reverbnation.com
# 998  1000   Maribelle        Rotge          mrotgerr@google.co.uk
#
#                    department  team_id  grade                 country  \
# 0                       Legal        9    0.0                 Nigeria
# 20            Human Resources        4    0.0             Philippines
# 70   Research and Development        5    0.0                   China
# 83                      Legal        5    0.0                   China
# 93                      Sales        7    0.0                   China
# 110               Engineering        4    0.0                  Brazil
# 153  Research and Development        3    1.0               Indonesia
# 154                 Marketing        1    1.0                  Brazil
# 158                   Support        1    0.0                  Russia
# 196                     Sales        9    0.0               Indonesia
# 216                  Training        2    0.0                  Brazil
# 226           Human Resources        8    0.0                Colombia
# 255           Human Resources        7    0.0             Afghanistan
# 261               Engineering        5    0.0               Indonesia
# 268                  Services        2    0.0                  Mexico
# 271      Business Development        9    0.0                  Russia
# 289                     Sales        6    0.0                 Finland
# 310        Product Management       10    0.0                  Russia
# 311                  Training        1    0.0               Indonesia
# 339        Product Management       10    0.0           United States
# 352  Research and Development       10    0.0  Bosnia and Herzegovina
# 355        Product Management       10    0.0                Portugal
# 366                     Sales        3    0.0           United States
# 394                Accounting        2    0.0                  Russia
# 406      Business Development        6    0.0                  Greece
# 419      Business Development        6    0.0             El Salvador
# 427               Engineering        3    1.0                  Serbia
# 444           Human Resources        7    0.0             Philippines
# 446                   Support        1    0.0                    Iran
# 454               Engineering        7    0.0             Philippines
# 533      Business Development        9    0.0                   China
# 563                     Sales        7    1.0               Macedonia
# 567               Engineering        1    0.0                   China
# 582        Product Management        7    0.0                   China
# 616                  Training        8    0.0                   Italy
# 677                     Sales        1    1.0   Palestinian Territory
# 686                 Marketing        3    0.0                  Sweden
# 691                     Legal        6    0.0                   Yemen
# 713           Human Resources        4    0.0                  France
# 762                Accounting        3    0.0                   China
# 780  Research and Development       10    0.0              East Timor
# 792                   Support        8    0.0             Afghanistan
# 795                Accounting        2    0.0                  France
# 824                  Services        6    1.0               Indonesia
# 858                     Legal        3    0.0               Indonesia
# 861                Accounting        6    0.0               Indonesia
# 881                Accounting        6    0.0                  Greece
# 901                     Legal        6    0.0                Tanzania
# 902        Product Management        5    0.0                  Brazil
# 919           Human Resources        8    1.0                 Georgia
# 920           Human Resources        9    1.0                  Zambia
# 974                  Training        7    0.0                 Mayotte
# 998  Research and Development        5    0.0                  Brazil
#
#      fte_hours pension_enrol   salary  pay_detail_id start_date  \
# 0         0.25           Yes  97667.0              1 2014-12-25
# 20        0.25           Yes  95805.0             22 2017-03-15
# 70        0.50            No  88922.0             72 1997-04-28
# 83        0.50            No  37548.0             85 2018-02-18
# 93        0.50           Yes  95166.0             95 2013-07-03
# 110       0.75           Yes  83727.0            112 2008-12-20
# 153       1.00            No  96722.0            155 1998-01-10
# 154       0.50           Yes  52506.0            156 1991-11-27
# 158       1.00            No  71750.0            160 1992-10-28
# 196       0.25           Yes  49588.0            198 2013-11-25
# 216       1.00           Yes  58816.0            218 2003-04-16
# 226       0.50           Yes  64078.0            228 2014-01-05
# 255       0.75            No  89578.0            257 1996-07-14
# 261       1.00            No  33041.0            263 1993-07-09
# 268       0.75            No  98524.0            270 2006-10-07
# 271       0.75            No      NaN            273 1990-04-06
# 289       0.50           Yes      NaN            291 2009-10-10
# 310       0.50           NaN  26388.0            312 1997-07-26
# 311       0.50           Yes  63299.0            313 2001-01-10
# 339       0.75           Yes  50195.0            341 2003-05-09
# 352       0.25            No      NaN            354 1992-11-06
# 355       0.50           Yes  47279.0            357 1996-03-23
# 366       0.75           NaN  72010.0            368 2004-12-15
# 394       0.50           Yes  65410.0            396 1992-06-05
# 406       0.25            No  58385.0            408 1996-12-02
# 419       0.25            No  34918.0            421 2006-05-10
# 427       1.00            No  74285.0            429 1997-08-22
# 444       0.25            No  33021.0            446 2005-04-27
# 446       0.25           Yes  55540.0            448 2003-06-08
# 454       0.50           Yes      NaN            456 2002-11-20
# 533       0.50           Yes  65142.0            535 2006-10-08
# 563       1.00            No  29450.0            565 2013-12-12
# 567       0.50            No  68935.0            569 2012-10-23
# 582       0.25           Yes      NaN            584 2015-10-20
# 616       1.00           Yes  86723.0            617        NaT
# 677       0.50            No  64603.0            678 2000-07-03
# 686       0.75            No  44598.0            687 2003-10-08
# 691       0.50           Yes  46084.0            692 2010-01-03
# 713       1.00            No  97626.0            715 2001-01-27
# 762       0.75            No  87043.0            764 2015-04-20
# 780       1.00           Yes  35866.0            782 1994-04-29
# 792       1.00           Yes  32849.0            794 2017-05-02
# 795       0.50            No  53792.0            797 2007-12-14
# 824       1.00           NaN  51628.0            826 2018-10-03
# 858       1.00            No  98422.0            860 2008-02-25
# 861       0.50           NaN  67882.0            863 2004-07-21
# 881       1.00            No  80988.0            883 1992-01-07
# 901       0.50            No  75063.0            903 2001-01-01
# 902       0.25           Yes  65009.0            904 1995-10-16
# 919       1.00            No  62858.0            921        NaT
# 920       0.25            No  35786.0            922 1991-07-23
# 974       0.75            No  89297.0            976 2008-05-30
# 998       0.50           Yes  62531.0           1000 2019-03-09
#
#      effective_salary
# 0            24416.75
# 20           23951.25
# 70           44461.00
# 83           18774.00
# 93           47583.00
# 110          62795.25
# 153          96722.00
# 154          26253.00
# 158          71750.00
# 196          12397.00
# 216          58816.00
# 226          32039.00
# 255          67183.50
# 261          33041.00
# 268          73893.00
# 271               NaN
# 289               NaN
# 310          13194.00
# 311          31649.50
# 339          37646.25
# 352               NaN
# 355          23639.50
# 366          54007.50
# 394          32705.00
# 406          14596.25
# 419           8729.50
# 427          74285.00
# 444           8255.25
# 446          13885.00
# 454               NaN
# 533          32571.00
# 563          29450.00
# 567          34467.50
# 582               NaN
# 616          86723.00
# 677          32301.50
# 686          33448.50
# 691          23042.00
# 713          97626.00
# 762          65282.25
# 780          35866.00
# 792          32849.00
# 795          26896.00
# 824          51628.00
# 858          98422.00
# 861          33941.00
# 881          80988.00
# 901          37531.50
# 902          16252.25
# 919          62858.00
# 920           8946.50
# 974          66972.75
# 998          31265.50

# %% [markdown]
# ***Q14.*** [**Harder**] Are there any `employees` whose `last_name` does not start with a capital letter?
#
# **Hints**
#
# * Assume there are no missing values in `last_name`
# * The `.str.startswith()` method won't accept regex, unfortunately
# * Regex **anchors** may help here: `^` means 'the position just before the start of a string, and `$` means 'the position just after the end of a string'
# * Remember `~` is the negation operator in `pandas`

# %%
# Don't need a capture group with .str.contains() 
employees.loc[~employees.last_name.str.contains(r'^[A-Z]'), 'id'].count()

# or
employees.loc[~employees.last_name.str.contains(r'^[A-Z]')].shape[0]
# Out:
# 5

# %% [markdown]
# ***Q15.*** Create a new column `start_month` in `employees`, containing the month in which an employee started with the corporation. Make `start_month` a string rather than a number, e.g. 'June' rather than '6'.
#
# **Hint** - Remember you can access `DatetimeProperties` using the `.dt` accessor

# %%
employees.loc[:, 'start_month'] = employees.start_date.dt.month_name()
employees.head()
# Out:
#    id first_name  last_name                    email          department  \
# 0   1      Ibbie   Roscrigg     iroscrigg0@google.fr               Legal
# 1   2      Sylas  Smallcomb                      NaN            Training
# 2   4     Osmund     Kittel   okittel3@bloomberg.com               Legal
# 3   5    Feodora   Dumingos  fdumingos4@bandcamp.com         Engineering
# 4   6      Peter    de Vaen         pdevaen5@mail.ru  Product Management
#
#    team_id  grade         country  fte_hours pension_enrol   salary  \
# 0        9    0.0         Nigeria       0.25           Yes  97667.0
# 1        3    0.0       Macedonia       0.75            No  48556.0
# 2       10    0.0  United Kingdom       1.00           Yes  51200.0
# 3        2    0.0       Indonesia       0.50           Yes  60460.0
# 4        2    1.0          Greece       0.50            No  32060.0
#
#    pay_detail_id start_date  effective_salary start_month
# 0              1 2014-12-25          24416.75    December
# 1              2 1991-08-01          36417.00      August
# 2              4 2007-09-06          51200.00   September
# 3              5 1990-03-28          30230.00       March
# 4              6 1992-06-30          16030.00        June

# %% [markdown]
# ***Q16.*** Obtain a table showing the number of `employees` in each `department`.
#
# **Hint** - Think **split-apply-combine**

# %%
employees.groupby('department', as_index=False).id.count()
# Out:
#                   department   id
# 0                 Accounting   72
# 1       Business Development   77
# 2                Engineering   87
# 3            Human Resources   90
# 4                      Legal  102
# 5                  Marketing   84
# 6         Product Management   79
# 7   Research and Development   94
# 8                      Sales   80
# 9                   Services   73
# 10                   Support   81
# 11                  Training   81

# %% [markdown]
# ***Q17.*** Obtain a count of the number of `employees` enrolled and not enrolled in the pension scheme. Ignore missing values in `pension_enrol` for now.

# %%
employees.groupby('pension_enrol', as_index=False).id.count()
# Out:
#   pension_enrol   id
# 0            No  470
# 1           Yes  488

# %% [markdown]
# ***Q18.*** [**Harder**] Repeat your analysis from Question 17 above, but this time fill any missing values in `pension_enrol` with the string 'Missing'.
#
# **Hint** - the `.fillna()` method will help here

# %%
employees.fillna({'pension_enrol': 'Missing'}).groupby('pension_enrol', as_index=False).id.count()
# Out:
#   pension_enrol   id
# 0       Missing   42
# 1            No  470
# 2           Yes  488

# %% [markdown]
# ***Q19.*** Obtain a count by `department` of the number of `employees` enrolled and not enrolled in the pension scheme. Include missing values or otherwise fill them with the string 'Missing' as in the Question above. [**Harder**] - Change the header of the column containing count values to 'num_employees'
#
# **Hints**
#
# * You need to `.groupby()` on multiple columns
# * Is there an argument to `.groupby()` that lets you keep missing values?
# * The `.agg()` method can take arguments that let you specify the output column name for an aggregator

# %%
# basic version
employees\
    .groupby(['department', 'pension_enrol'], dropna=False, as_index=False)\
    .id.count()

# version recoding 'Missing' and changing aggregator column header
employees\
    .fillna({'department': 'Missing', 'pension_enrol': 'Missing'})\
    .groupby(['department', 'pension_enrol'], as_index=False)\
    .agg(num_employees = ('id', 'count'))
# Out:
#                   department pension_enrol  num_employees
# 0                 Accounting       Missing              3
# 1                 Accounting            No             37
# 2                 Accounting           Yes             32
# 3       Business Development       Missing              1
# 4       Business Development            No             43
# 5       Business Development           Yes             33
# 6                Engineering       Missing              5
# 7                Engineering            No             37
# 8                Engineering           Yes             45
# 9            Human Resources       Missing              5
# 10           Human Resources            No             44
# 11           Human Resources           Yes             41
# 12                     Legal       Missing              8
# 13                     Legal            No             42
# 14                     Legal           Yes             52
# 15                 Marketing       Missing              3
# 16                 Marketing            No             42
# 17                 Marketing           Yes             39
# 18        Product Management       Missing              3
# 19        Product Management            No             41
# 20        Product Management           Yes             35
# 21  Research and Development       Missing              2
# 22  Research and Development            No             43
# 23  Research and Development           Yes             49
# 24                     Sales       Missing              5
# 25                     Sales            No             33
# 26                     Sales           Yes             42
# 27                  Services       Missing              2
# 28                  Services            No             35
# 29                  Services           Yes             36
# 30                   Support       Missing              2
# 31                   Support            No             32
# 32                   Support           Yes             47
# 33                  Training       Missing              3
# 34                  Training            No             41
# 35                  Training           Yes             37

# %% [markdown]
# ***Q20.*** Obtain a table showing all `employees` details together with a column `team_name` containing the name of their team.
#
# **Attempt this question only after the lesson on joining, melting and pivoting `DataFrame`s on day 3**
#
# **Hints**
#
# * This will require joining `employees` to `teams`
# * You can `.drop()` unwanted columns from `teams` after the join
# * The `.rename()` method lets you change column names

# %%
employees.merge(teams, how='left', left_on='team_id', right_on='id')\
    .drop(['id_y', 'charge_cost', 'team_id'], axis='columns')\
    .rename(columns={'id_x': 'id', 'name': 'team_name'})
# Out:
#        id first_name  last_name                    email  \
# 0       1      Ibbie   Roscrigg     iroscrigg0@google.fr
# 1       2      Sylas  Smallcomb                      NaN
# 2       4     Osmund     Kittel   okittel3@bloomberg.com
# 3       5    Feodora   Dumingos  fdumingos4@bandcamp.com
# 4       6      Peter    de Vaen         pdevaen5@mail.ru
# ..    ...        ...        ...                      ...
# 995   997    Carlina      Pirot     cpirotro@archive.org
# 996   998     Wileen     Skones        wskonesrp@hhs.gov
# 997   999      Willy     Dulake  wdulakerq@webeden.co.uk
# 998  1000  Maribelle      Rotge    mrotgerr@google.co.uk
# 999     3     Saleem      Adame       sadame3@utexas.edu
#
#                    department  grade         country  fte_hours pension_enrol  \
# 0                       Legal    0.0         Nigeria       0.25           Yes
# 1                    Training    0.0       Macedonia       0.75            No
# 2                       Legal    0.0  United Kingdom       1.00           Yes
# 3                 Engineering    0.0       Indonesia       0.50           Yes
# 4          Product Management    1.0          Greece       0.50            No
# ..                        ...    ...             ...        ...           ...
# 995      Business Development    0.0           China       1.00            No
# 996                Accounting    0.0          Uganda       0.25           Yes
# 997      Business Development    0.0        Colombia       0.25            No
# 998  Research and Development    0.0          Brazil       0.50           Yes
# 999                  Services    0.0        Portugal       0.25           Yes
#
#       salary  pay_detail_id start_date  effective_salary start_month  \
# 0    97667.0              1 2014-12-25          24416.75    December
# 1    48556.0              2 1991-08-01          36417.00      August
# 2    51200.0              4 2007-09-06          51200.00   September
# 3    60460.0              5 1990-03-28          30230.00       March
# 4    32060.0              6 1992-06-30          16030.00        June
# ..       ...            ...        ...               ...         ...
# 995  63189.0            997 2018-08-30          63189.00      August
# 996  81734.0            998 2000-11-26          20433.50    November
# 997  21590.0            999 2018-08-01           5397.50      August
# 998  62531.0           1000 2019-03-09          31265.50       March
# 999  91749.0              3 1999-10-09          22937.25     October
#
#           team_name
# 0     Data Escalate
# 1       Risk Team 1
# 2         Corporate
# 3      Audit Team 2
# 4      Audit Team 2
# ..              ...
# 995    Audit Team 2
# 996     Risk Team 2
# 997   Data Escalate
# 998  Audit Escalate
# 999   Data Escalate
#
# [1000 rows x 15 columns]

# %% [markdown]
# ***Q21.*** [**Harder**] Obtain a table showing `team_name` together with a count of the `num_employees` in each team.
#
# **Attempt this question only after the lesson on joining, melting and pivoting `DataFrame`s on day 3**
#
# **Hints**
#
# * You will need to join `employees` to `teams`
# * The `.rename()` method lets you rename a column
# * The `.agg()` method can take arguments that let you specify the output column name for an aggregator

# %%
employees.merge(teams, how='right', left_on='team_id', right_on='id')\
    .rename(columns={'name': 'team_name'})\
    .groupby('team_name', as_index=False)\
    .agg(num_employees=('id_x', 'count'))
# Out:
#         team_name  num_employees
# 0  Audit Escalate             99
# 1    Audit Team 1            113
# 2    Audit Team 2            107
# 3       Corporate             92
# 4   Data Escalate             99
# 5     Data Team 1             99
# 6     Data Team 2             96
# 7   Risk Escalate            105
# 8     Risk Team 1             85
# 9     Risk Team 2            105

# %% [markdown]
# ***Q22.*** [**Harder**] Obtain a table showing the `id`, `first_name`, `last_name` and `department` of any `employees` lacking both a `local_account_no` and `local_sort_code` in their `pay_details`.
#
# **Attempt this question only after the lesson on joining, melting and pivoting `DataFrame`s on day 3**
#
# **Hints**
#
# * Filter `pay_details` down to those rows lacking both a `local_account_no` and `local_sort_code`, and then join that to `employees`
# * The `.all()` method applied over columns can help here

# %%
employees\
    .merge(
        pay_details.loc[pay_details[['local_account_no', 'local_sort_code']].isna().all(axis='columns')],
        how='inner',
        left_on='pay_detail_id',
        right_on='id'
    )\
    .rename(columns={'id_x': 'id'})\
    .loc[:, ['id', 'first_name', 'last_name', 'department']]
# Out:
#      id first_name   last_name                department
# 0    48     Barney   Yakovitch        Product Management
# 1    57      Rheba      Booton               Engineering
# 2    63    Reynard      Jonson                     Legal
# 3    94     Darsey      Cescon                Accounting
# 4   147      Hubie      Butter               Engineering
# 5   150       Elsi     Norquay                  Training
# 6   187     Brande       Crump                 Marketing
# 7   208    Abigael    McArthur      Business Development
# 8   245   Stillman     Brislen           Human Resources
# 9   267    Bernarr       Nolan      Business Development
# 10  322     Hamlen     Bretton                   Support
# 11  358     Davide       Chadd                     Legal
# 12  451        Cam       Tidey                     Legal
# 13  461       Dalt     Hugland                     Sales
# 14  484        NaN       Braim                     Legal
# 15  496        Viv    Stanluck                  Training
# 16  505     Shalom     Oldaker  Research and Development
# 17  565       Bell      Riolfi                     Sales
# 18  648     Cirilo     Brangan                     Legal
# 19  690    Haskell    Josefson               Engineering
# 20  719     Weidar       Joost                 Marketing
# 21  725     Ellery     Hanford                 Marketing
# 22  800       Karl    Kalberer                     Legal
# 23  881   Filberte  Houldcroft                Accounting
# 24  914     Daveen    De Lasci                   Support

# %% [markdown]
# # Extension question solutions
#
# ***Q1.*** Investigate the use of the `.where()` function in the `numpy` package to add a column `hours_class` to `employees` containing the value 'low' when `fte_hours` is 0.5 or less and 'high' otherwise.
#
# **Hint** - Import `numpy` as `np`, and `.where()` will then be available as `np.where()`

# %%
import numpy as np

employees.loc[:, 'hours_class'] = np.where(employees.fte_hours <= 0.5, 'low', 'high')
# or
employees = employees.assign(hours_class = np.where(employees.fte_hours <= 0.5, 'low', 'high'))

# %% [markdown]
# ***Q2.*** Are there any `employees` with invalid `email` addresses?
#
# **Hint** - look for non-null `email` addresses that don't match a reasonable regex pattern for a valid email address

# %%
employees.loc[
    ~employees.email.str.contains(r'[\w\.]+@[\w\.]+', na=False) & 
    employees.email.notnull(),
    'id'
].count()

# or 
employees.loc[
    ~employees.email.str.contains(r'[\w\.]+@[\w\.]+', na=False) & 
    employees.email.notnull()
].shape[0]
# Out:
# 0

# %% [markdown]
# ***Q3.*** How many of the `employees` serve on one or more `committees`?
#
# **Hints**
#
# * This requires only the `employees_committees` `DataFrame`
# * Think about distinct `employees`

# %%
employees_committees.employee_id.nunique()
# Out:
# 22

# %% [markdown]
# ***Q4.*** Get the full employee details [including committee name(s)] of any committee members based in the Ukraine.
#
# **Attempt this question only after the lesson on joining, melting and pivoting `DataFrame`s on day 3**
#
# **Hints**
#
# * this is a many-to-many join, so three `DataFrame`s will be involved: `employees`, `committees` and `employees_committees`
# * The `.query()` method lets you do all this in one line of code

# %%
employees.merge(employees_committees, how='right', left_on='id', right_on='employee_id')\
    .merge(committees, how='left', left_on='committee_id', right_on='id')\
    .drop(columns=['employee_id', 'id_y', 'committee_id', 'id'])\
    .rename(columns={'id_x': 'id', 'name': 'committee_name'})\
    .query("country == 'Ukraine'")
# Out:
#     id first_name     last_name                      email department  \
# 2  434        Sax  Zmitrichenko  szmitrichenkoc1@slate.com      Legal
# 3  434        Sax  Zmitrichenko  szmitrichenkoc1@slate.com      Legal
#
#    team_id  grade  country  fte_hours pension_enrol   salary  pay_detail_id  \
# 2        7    0.0  Ukraine        0.5           Yes  46928.0            434
# 3        7    0.0  Ukraine        0.5           Yes  46928.0            434
#
#   start_date  effective_salary start_month hours_class     committee_name
# 2 2002-08-20           23464.0      August         low  Health and Safety
# 3 2002-08-20           23464.0      August         low             Social

# %% [markdown]
# ***Q5.*** Obtain a table with column `start_month` containing the names of months and column `num_started` showing the number of `employees` who started in that month (in any year). The table should contain 12 rows, one for each month, and be ordered 'January', 'February', 'March' and so forth, in ascending calendar order.
#
# **Hints**
#
# * Extracting both the `.month_name()` and `.month` from `start_date` might help here
# * We used `.assign()` to create the two new date feature columns before any subsequent operations

# %%
employees.assign(
        start_month=employees.start_date.dt.month_name(),
        start_month_num=employees.start_date.dt.month)\
    .groupby(['start_month', 'start_month_num'], as_index=False).agg(num_started=('id', 'count'))\
    .sort_values('start_month_num')\
    .drop(columns=['start_month_num'])\
    .reset_index(drop=True)
# Out:
#    start_month  num_started
# 0      January           83
# 1     February           69
# 2        March           89
# 3        April           62
# 4          May           77
# 5         June           75
# 6         July           93
# 7       August           87
# 8    September           68
# 9      October           83
# 10    November           72
# 11    December           68
